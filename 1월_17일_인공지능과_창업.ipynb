# %% [markdown]
# <a href="https://colab.research.google.com/github/Myonmyon99/MYON/blob/main/1%EC%9B%94_17%EC%9D%BC_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EA%B3%BC_%EC%B0%BD%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10

# %%
print(a)
# Out:
#   File "<ipython-input-2-290ba29d8057>", line 1
#     [2] 1 print(a)
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_excel('통합 문서1.xlsx', header=None)
df
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60

# %%
import pandas as pd
df=pd.read_csv('student.csv')
df.weight
# Out:
# 0    65
# 1    52
# 2    70
# 3    80
# Name: weight, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('student.csv')
df['weight']
# Out:
# 0    65
# 1    52
# 2    70
# 3    80
# Name: weight, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('student.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  4 non-null      float64
#  1   weight  4 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 192.0 bytes

# %%
ddf=pd.read_csv('Student_Marks.csv')
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
ddf=pd.read_csv('Student_Marks.csv')
ddf.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
df.isnull().sum()
# Out:
# height    0
# weight    0
# dtype: int64
